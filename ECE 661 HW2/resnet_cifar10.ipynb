# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# !unzip tools -f
# Out:
# Archive:  tools.zip
# caution: filename not matched:  -f

# %%
os.makedirs('saved_model', exist_ok = True)

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init


class ResidulBlock(nn.Module):
    expansion = 1

    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidulBlock, self).__init__()
        self.conv1 = nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(outchannel)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(outchannel)
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = self.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.linear = nn.Linear(64, num_classes)


    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion

        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)

        out = self.bn1(out)
        out = F.relu(out)
        out = self.layer1(out)

        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def resnet20():
    return ResNet(ResidulBlock, [3, 3, 3])

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)
# specify preprocessing function

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

# %%
# your code here
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU")
else:
    device = torch.device("cpu")
    print("Using CPU")


model = resnet20()
model = model.to(device)
print(model)
# Out:
# Using GPU
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): ResidulBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): ResidulBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): ResidulBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): ResidulBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidulBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): ResidulBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): ResidulBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidulBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): ResidulBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT,
    mode='train',
    download=True,
    transform=transform_train    # your code
)
val_set = CIFAR10(
    root=DATA_ROOT,
    mode='val',
    download=True,
    transform=transform_val    # your code
)

# construct dataloader
train_loader = DataLoader(
    train_set,
    batch_size=TRAIN_BATCH_SIZE,  # your code
    shuffle=torch.triu_indices,     # your code
    num_workers=16
)
val_loader = DataLoader(
    val_set,
    batch_size=VAL_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=16
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1
UPDATED_LR=0.01

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 1e-4

#############################################
# your code here
# create loss function
criterion =nn.CrossEntropyLoss()

# Add optimizer
optimizer =optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)
#############################################

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 200

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "/content/saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    #######################
    # your code here
    # switch to train mode
    model.train()


    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0
    val_loss = 0

    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
         inputs, targets = inputs.to(device), targets.to(device)

         # compute the output and loss
         output= model(inputs)
         loss= criterion(output,targets)

         # zero the gradient

         optimizer.zero_grad()
         # backpropagation
         loss.backward()


        # apply gradient and update the weights
         optimizer.step()


        # count the number of correctly predicted samples in the current batch
         _, predicted = output.max(1)
         total_examples += targets.size(0)
         correct_examples += predicted.eq(targets).sum().item()
         train_loss += loss.item()

        ####################################

    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    model.eval()


    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0

    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs, targets =inputs.to(device), targets.to(device)


            # compute the output and loss
            output=model(inputs)
            loss= criterion(output,targets)


            # count the number of correctly predicted samples in the current batch
            _, predicted = output.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss.item()

            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    if i == 40:
        for param_group in optimizer.param_groups:
            param_group['lr'] = UPDATED_LR

    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
           os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                'epoch': i,
                'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'simplenn.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.6769, Training accuracy: 0.3690
# Validation loss: 1.3773, Validation accuracy: 0.4944
# Saving ...
#
# Epoch 1:
# Training loss: 1.1992, Training accuracy: 0.5642
# Validation loss: 1.3483, Validation accuracy: 0.5478
# Saving ...
#
# Epoch 2:
# Training loss: 0.9674, Training accuracy: 0.6546
# Validation loss: 0.9725, Validation accuracy: 0.6566
# Saving ...
#
# Epoch 3:
# Training loss: 0.8310, Training accuracy: 0.7085
# Validation loss: 0.8512, Validation accuracy: 0.6970
# Saving ...
#
# Epoch 4:
# Training loss: 0.7242, Training accuracy: 0.7465
# Validation loss: 0.8485, Validation accuracy: 0.7146
# Saving ...
#
# Epoch 5:
# Training loss: 0.6593, Training accuracy: 0.7702
# Validation loss: 0.7961, Validation accuracy: 0.7290
# Saving ...
#
# Epoch 6:
# Training loss: 0.6104, Training accuracy: 0.7903
# Validation loss: 0.7677, Validation accuracy: 0.7506
# Saving ...
#
# Epoch 7:
# Training loss: 0.5692, Training accuracy: 0.8041
# Validation loss: 0.7794, Validation accuracy: 0.7400
#
# Epoch 8:
# Training loss: 0.5425, Training accuracy: 0.8122
# Validation loss: 0.6112, Validation accuracy: 0.7940
# Saving ...
#
# Epoch 9:
# Training loss: 0.5144, Training accuracy: 0.8236
# Validation loss: 0.5880, Validation accuracy: 0.8058
# Saving ...
#
# Epoch 10:
# Training loss: 0.4953, Training accuracy: 0.8279
# Validation loss: 0.7945, Validation accuracy: 0.7492
#
# Epoch 11:
# Training loss: 0.4766, Training accuracy: 0.8351
# Validation loss: 0.6180, Validation accuracy: 0.7986
#
# Epoch 12:
# Training loss: 0.4577, Training accuracy: 0.8409
# Validation loss: 0.5155, Validation accuracy: 0.8320
# Saving ...
#
# Epoch 13:
# Training loss: 0.4392, Training accuracy: 0.8481
# Validation loss: 0.6479, Validation accuracy: 0.7898
#
# Epoch 14:
# Training loss: 0.4297, Training accuracy: 0.8507
# Validation loss: 0.5441, Validation accuracy: 0.8104
#
# Epoch 15:
# Training loss: 0.4211, Training accuracy: 0.8537
# Validation loss: 0.6033, Validation accuracy: 0.7968
#
# Epoch 16:
# Training loss: 0.4087, Training accuracy: 0.8585
# Validation loss: 0.6743, Validation accuracy: 0.7924
#
# Epoch 17:
# Training loss: 0.3960, Training accuracy: 0.8634
# Validation loss: 0.5799, Validation accuracy: 0.8118
#
# Epoch 18:
# Training loss: 0.3866, Training accuracy: 0.8658
# Validation loss: 0.5818, Validation accuracy: 0.8186
#
# Epoch 19:
# Training loss: 0.3773, Training accuracy: 0.8682
# Validation loss: 0.5656, Validation accuracy: 0.8204
#
# Epoch 20:
# Training loss: 0.3718, Training accuracy: 0.8708
# Validation loss: 0.6149, Validation accuracy: 0.8060
#
# Epoch 21:
# Training loss: 0.3661, Training accuracy: 0.8728
# Validation loss: 0.4708, Validation accuracy: 0.8424
# Saving ...
#
# Epoch 22:
# Training loss: 0.3588, Training accuracy: 0.8758
# Validation loss: 0.6421, Validation accuracy: 0.8084
#
# Epoch 23:
# Training loss: 0.3487, Training accuracy: 0.8782
# Validation loss: 0.4405, Validation accuracy: 0.8494
# Saving ...
#
# Epoch 24:
# Training loss: 0.3437, Training accuracy: 0.8807
# Validation loss: 0.4497, Validation accuracy: 0.8464
#
# Epoch 25:
# Training loss: 0.3405, Training accuracy: 0.8842
# Epoch 150:
# Training loss: 0.0438, Training accuracy: 0.9855
# Validation loss: 0.4565, Validation accuracy: 0.8996
#
# Epoch 151:
# Training loss: 0.0452, Training accuracy: 0.9847
# Validation loss: 0.4544, Validation accuracy: 0.8968
#
# Epoch 152:
# Training loss: 0.0441, Training accuracy: 0.9850
# Validation loss: 0.5006, Validation accuracy: 0.8914
#
# Epoch 153:
# Training loss: 0.0435, Training accuracy: 0.9848
# Validation loss: 0.4546, Validation accuracy: 0.8996
#
# Epoch 154:
# Training loss: 0.0474, Training accuracy: 0.9835
# Validation loss: 0.4771, Validation accuracy: 0.8970
#
# Epoch 155:
# Training loss: 0.0470, Training accuracy: 0.9839
# Validation loss: 0.4687, Validation accuracy: 0.8998
#
# Epoch 156:
# Training loss: 0.0472, Training accuracy: 0.9836
# Validation loss: 0.4796, Validation accuracy: 0.8958
#
# Epoch 157:
# Training loss: 0.0461, Training accuracy: 0.9845
# Validation loss: 0.4738, Validation accuracy: 0.8942
#
# Epoch 158:
# Training loss: 0.0439, Training accuracy: 0.9846
# Validation loss: 0.4507, Validation accuracy: 0.9012
#
# Epoch 159:
# Training loss: 0.0424, Training accuracy: 0.9857
# Validation loss: 0.4577, Validation accuracy: 0.8966
#
# Epoch 160:
# Training loss: 0.0444, Training accuracy: 0.9849
# Validation loss: 0.4771, Validation accuracy: 0.8982
#
# Epoch 161:
# Training loss: 0.0448, Training accuracy: 0.9844
# Validation loss: 0.4617, Validation accuracy: 0.8952
#
# Epoch 162:
# Training loss: 0.0484, Training accuracy: 0.9832
# Validation loss: 0.4424, Validation accuracy: 0.9008
#
# Epoch 163:
# Training loss: 0.0469, Training accuracy: 0.9845
# Validation loss: 0.4541, Validation accuracy: 0.8982
#
# Epoch 164:
# Training loss: 0.0451, Training accuracy: 0.9842
# Validation loss: 0.4283, Validation accuracy: 0.9030
#
# Epoch 165:
# Training loss: 0.0442, Training accuracy: 0.9849
# Validation loss: 0.4617, Validation accuracy: 0.9010
#
# Epoch 166:
# Training loss: 0.0425, Training accuracy: 0.9853
# Validation loss: 0.4786, Validation accuracy: 0.8950
#
# Epoch 167:
# Training loss: 0.0421, Training accuracy: 0.9847
# Validation loss: 0.4536, Validation accuracy: 0.8998
#
# Epoch 168:
# Training loss: 0.0425, Training accuracy: 0.9858
# Validation loss: 0.4522, Validation accuracy: 0.9000
#
# Epoch 169:
# Training loss: 0.0411, Training accuracy: 0.9856
# Validation loss: 0.4529, Validation accuracy: 0.9008
#
# Epoch 170:
# Training loss: 0.0487, Training accuracy: 0.9829
# Validation loss: 0.4752, Validation accuracy: 0.8996
#
# Epoch 171:
# Training loss: 0.0478, Training accuracy: 0.9831
# Validation loss: 0.4434, Validation accuracy: 0.8972
#
# Epoch 172:
# Training loss: 0.0443, Training accuracy: 0.9852
# Validation loss: 0.4383, Validation accuracy: 0.9026
#
# Epoch 173:
# Training loss: 0.0435, Training accuracy: 0.9846
# Validation loss: 0.4289, Validation accuracy: 0.9004
#
# Epoch 174:
# Training loss: 0.0416, Training accuracy: 0.9859
# Validation loss: 0.4533, Validation accuracy: 0.8984
#
# Epoch 175:
# Training loss: 0.0415, Training accuracy: 0.9858
# Validation loss: 0.4731, Validation accuracy: 0.8946
#
# Epoch 176:
# Training loss: 0.0431, Training accuracy: 0.9854
# Validation loss: 0.4749, Validation accuracy: 0.8950
#
# Epoch 177:
# Training loss: 0.0452, Training accuracy: 0.9849
# Validation loss: 0.5251, Validation accuracy: 0.8922
#
# Epoch 178:
# Training loss: 0.0466, Training accuracy: 0.9840
# Validation loss: 0.4464, Validation accuracy: 0.8994
#
# Epoch 179:
# Training loss: 0.0424, Training accuracy: 0.9849
# Validation loss: 0.4409, Validation accuracy: 0.8986
#
# Epoch 180:
# Training loss: 0.0425, Training accuracy: 0.9853
# Validation loss: 0.4426, Validation accuracy: 0.8996
#
# Epoch 181:
# Training loss: 0.0410, Training accuracy: 0.9856
# Validation loss: 0.4583, Validation accuracy: 0.8984
#
# Epoch 182:
# Training loss: 0.0435, Training accuracy: 0.9847
# Validation loss: 0.5173, Validation accuracy: 0.8874
#
# Epoch 183:
# Training loss: 0.0413, Training accuracy: 0.9866
# Validation loss: 0.4523, Validation accuracy: 0.8984
#
# Epoch 184:
# Training loss: 0.0440, Training accuracy: 0.9851
# Validation loss: 0.4762, Validation accuracy: 0.8946
#
# Epoch 185:
# Training loss: 0.0422, Training accuracy: 0.9857
# Validation loss: 0.4651, Validation accuracy: 0.8962
#
# Epoch 186:
# Training loss: 0.0448, Training accuracy: 0.9846
# Validation loss: 0.4592, Validation accuracy: 0.8962
#
# Epoch 187:
# Training loss: 0.0453, Training accuracy: 0.9842
# Validation loss: 0.4544, Validation accuracy: 0.8988
#
# Epoch 188:
# Training loss: 0.0453, Training accuracy: 0.9845
# Validation loss: 0.5027, Validation accuracy: 0.8920
#
# Epoch 189:
# Training loss: 0.0420, Training accuracy: 0.9863
# Validation loss: 0.4509, Validation accuracy: 0.9006
#
# Epoch 190:
# Training loss: 0.0420, Training accuracy: 0.9856
# Validation loss: 0.5338, Validation accuracy: 0.8836
#
# Epoch 191:
# Training loss: 0.0419, Training accuracy: 0.9858
# Validation loss: 0.4715, Validation accuracy: 0.8938
#
# Epoch 192:
# Training loss: 0.0418, Training accuracy: 0.9857
# Validation loss: 0.4582, Validation accuracy: 0.8974
#
# Epoch 193:
# Training loss: 0.0456, Training accuracy: 0.9846
# Validation loss: 0.4976, Validation accuracy: 0.8910
#
# Epoch 194:
# Training loss: 0.0456, Training accuracy: 0.9846
# Validation loss: 0.4652, Validation accuracy: 0.8922
#
# Epoch 195:
# Training loss: 0.0401, Training accuracy: 0.9862
# Validation loss: 0.4694, Validation accuracy: 0.9000
#
# Epoch 196:
# Training loss: 0.0408, Training accuracy: 0.9857
# Validation loss: 0.4731, Validation accuracy: 0.8920
#
# Epoch 197:
# Training loss: 0.0442, Training accuracy: 0.9846
# Validation loss: 0.4939, Validation accuracy: 0.8956
#
# Epoch 198:
# Training loss: 0.0460, Training accuracy: 0.9834
# Validation loss: 0.4938, Validation accuracy: 0.8890
#
# Epoch 199:
# Training loss: 0.0425, Training accuracy: 0.9854
# Validation loss: 0.4717, Validation accuracy: 0.9006
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9070
